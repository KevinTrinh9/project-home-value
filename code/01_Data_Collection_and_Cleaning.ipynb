# %% [markdown]
# # Factors Affecting the Value of Your Home

# %% [markdown]
# # Data Collection and Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in datasets
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %%
train.head()
# Out:
#    Unnamed: 0    Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  \
# 0         532  1612  526352080           20        RL          85.0     10667
# 1         415  2045  904100100           70        RL         107.0     12888
# 2         273  1962  535451110           20        RL          60.0      7200
# 3        1460   229  905109130           60        RL          80.0     14000
# 4         250  1105  528363020           60        RL           NaN     11929
#
#   Street Alley Lot Shape  ... Screen Porch Pool Area Pool QC Fence  \
# 0   Pave   NaN       Reg  ...            0         0     NaN   NaN
# 1   Pave   NaN       Reg  ...            0         0     NaN   NaN
# 2   Pave   NaN       Reg  ...            0         0     NaN   NaN
# 3   Pave   NaN       Reg  ...            0         0     NaN   NaN
# 4   Pave   NaN       IR1  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold Sale Type  SalePrice
# ...

# %%
test.head()
# Out:
#    Unnamed: 0    Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  \
# 0        1124  2782  907200170           80        RL          55.0     10780
# 1         188  2569  535125060           60        RL          88.0     14200
# 2        1727  1062  528142020           60        RL          74.0      8899
# 3        1658   287  909100110           70        RL          66.0      6858
# 4        1424  2809  907410040           60        RL          74.0      8581
#
#   Street Alley Lot Shape  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0   Pave   NaN       IR1  ...          0            0         0     NaN
# 1   Pave   NaN       Reg  ...          0            0         0     NaN
# 2   Pave   NaN       Reg  ...          0            0         0     NaN
# 3   Pave   NaN       Reg  ...          0            0         0     NaN
# 4   Pave   NaN       IR1  ...          0            0         0     NaN
#
#    Fence Misc Feature Misc Val Mo Sold Yr Sold  Sale Type
# ...

# %%
train.shape
# Out:
# (1538, 82)

# %%
test.shape
# Out:
# (513, 81)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1538 entries, 0 to 1537
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1538 non-null   int64
#  1   Id               1538 non-null   int64
#  2   PID              1538 non-null   int64
#  3   MS SubClass      1538 non-null   int64
#  4   MS Zoning        1538 non-null   object
#  5   Lot Frontage     1285 non-null   float64
#  6   Lot Area         1538 non-null   int64
#  7   Street           1538 non-null   object
#  8   Alley            111 non-null    object
#  9   Lot Shape        1538 non-null   object
#  10  Land Contour     1538 non-null   object
#  11  Utilities        1538 non-null   object
#  12  Lot Config       1538 non-null   object
#  13  Land Slope       1538 non-null   object
#  14  Neighborhood     1538 non-null   object
#  15  Condition 1      1538 non-null   object
#  16  Condition 2      1538 non-null   object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       513 non-null    int64
#  1   Id               513 non-null    int64
#  2   PID              513 non-null    int64
#  3   MS SubClass      513 non-null    int64
#  4   MS Zoning        513 non-null    object
#  5   Lot Frontage     436 non-null    float64
#  6   Lot Area         513 non-null    int64
#  7   Street           513 non-null    object
#  8   Alley            29 non-null     object
#  9   Lot Shape        513 non-null    object
#  10  Land Contour     513 non-null    object
#  11  Utilities        513 non-null    object
#  12  Lot Config       513 non-null    object
#  13  Land Slope       513 non-null    object
#  14  Neighborhood     513 non-null    object
#  15  Condition 1      513 non-null    object
#  16  Condition 2      513 non-null    object
# ...

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage',
#        'Lot Area', 'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
test.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage',
#        'Lot Area', 'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
# display summary statistics
train.describe()
# Out:
#         Unnamed: 0           Id           PID  MS SubClass  Lot Frontage  \
# count  1538.000000  1538.000000  1.538000e+03  1538.000000   1285.000000
# mean   1024.970741  1469.562419  7.118700e+08    56.983095     69.378210
# std     588.860047   840.814349  1.886513e+08    43.217246     24.095542
# min       0.000000     1.000000  5.263011e+08    20.000000     21.000000
# 25%     522.250000   748.250000  5.284562e+08    20.000000     58.000000
# 50%    1022.000000  1483.500000  5.354511e+08    50.000000     68.000000
# 75%    1528.750000  2189.750000  9.071308e+08    70.000000     80.000000
# max    2050.000000  2930.000000  9.241510e+08   190.000000    313.000000
#
#            Lot Area  Overall Qual  Overall Cond   Year Built  Year Remod/Add  \
# count   1538.000000   1538.000000   1538.000000  1538.000000     1538.000000
# mean    9955.676203      6.109883      5.559818  1971.860858     1984.168401
# std     5427.477335      1.428502      1.100363    30.173843       20.926357
# ...

# %%
# display summary statistics
test.describe()
# Out:
#         Unnamed: 0           Id           PID  MS SubClass  Lot Frontage  \
# count   513.000000   513.000000  5.130000e+02    513.00000    436.000000
# mean   1025.087719  1487.438596  7.187466e+08     57.08577     68.103211
# std     602.750588   854.090084  1.889035e+08     41.66501     20.600544
# min       2.000000    12.000000  5.263510e+08     20.00000     21.000000
# 25%     480.000000   803.000000  5.313761e+08     20.00000     57.000000
# 50%    1034.000000  1490.000000  5.354780e+08     50.00000     66.500000
# 75%    1573.000000  2231.000000  9.072540e+08     75.00000     80.000000
# max    2048.000000  2929.000000  9.241520e+08    190.00000    134.000000
#
#             Lot Area  Overall Qual  Overall Cond   Year Built  Year Remod/Add  \
# count     513.000000    513.000000    513.000000   513.000000      513.000000
# mean    10393.590643      6.118908      5.569201  1971.253411     1984.255361
# ...

# %%
train.isnull().sum()
# Out:
# Unnamed: 0     0
# Id             0
# PID            0
# MS SubClass    0
# MS Zoning      0
#               ..
# Misc Val       0
# Mo Sold        0
# Yr Sold        0
# Sale Type      0
# SalePrice      0
# Length: 82, dtype: int64

# %%
test.isnull().sum()
# Out:
# Unnamed: 0        0
# Id                0
# PID               0
# MS SubClass       0
# MS Zoning         0
#                ...
# Misc Feature    502
# Misc Val          0
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Length: 81, dtype: int64

# %%
train.dtypes
# Out:
# Unnamed: 0      int64
# Id              int64
# PID             int64
# MS SubClass     int64
# MS Zoning      object
#                 ...
# Misc Val        int64
# Mo Sold         int64
# Yr Sold         int64
# Sale Type      object
# SalePrice       int64
# Length: 82, dtype: object

# %%
test.dtypes
# Out:
# Unnamed: 0       int64
# Id               int64
# PID              int64
# MS SubClass      int64
# MS Zoning       object
#                  ...
# Misc Feature    object
# Misc Val         int64
# Mo Sold          int64
# Yr Sold          int64
# Sale Type       object
# Length: 81, dtype: object

# %%
# drop columns with more than 50% null values
threshold = 0.5 * len(train)
train_cleaned = train.dropna(thresh=threshold, axis=1)

# %%
train_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1538 entries, 0 to 1537
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1538 non-null   int64
#  1   Id               1538 non-null   int64
#  2   PID              1538 non-null   int64
#  3   MS SubClass      1538 non-null   int64
#  4   MS Zoning        1538 non-null   object
#  5   Lot Frontage     1285 non-null   float64
#  6   Lot Area         1538 non-null   int64
#  7   Street           1538 non-null   object
#  8   Lot Shape        1538 non-null   object
#  9   Land Contour     1538 non-null   object
#  10  Utilities        1538 non-null   object
#  11  Lot Config       1538 non-null   object
#  12  Land Slope       1538 non-null   object
#  13  Neighborhood     1538 non-null   object
#  14  Condition 1      1538 non-null   object
#  15  Condition 2      1538 non-null   object
#  16  Bldg Type        1538 non-null   object
# ...

# %%
# drop columns with more than 50% null values
threshold = 0.5 * len(test)
test_cleaned = test.dropna(thresh=threshold, axis=1)

# %%
test_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 76 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       513 non-null    int64
#  1   Id               513 non-null    int64
#  2   PID              513 non-null    int64
#  3   MS SubClass      513 non-null    int64
#  4   MS Zoning        513 non-null    object
#  5   Lot Frontage     436 non-null    float64
#  6   Lot Area         513 non-null    int64
#  7   Street           513 non-null    object
#  8   Lot Shape        513 non-null    object
#  9   Land Contour     513 non-null    object
#  10  Utilities        513 non-null    object
#  11  Lot Config       513 non-null    object
#  12  Land Slope       513 non-null    object
#  13  Neighborhood     513 non-null    object
#  14  Condition 1      513 non-null    object
#  15  Condition 2      513 non-null    object
#  16  Bldg Type        513 non-null    object
# ...

# %%
# fill missing data in numerical columns with average of columns' values
# fill missing data in categorical columns with 'Unknown'
numerical_columns = train_cleaned.select_dtypes(include=['int', 'float']).columns
train_cleaned.loc[:, numerical_columns] = train_cleaned.loc[:, numerical_columns].fillna(train_cleaned[numerical_columns].mean())
categorical_columns = train_cleaned.select_dtypes(include=['object']).columns
train_cleaned.loc[:, categorical_columns] = train_cleaned.loc[:, categorical_columns].fillna('Unknown')
train_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1538 entries, 0 to 1537
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1538 non-null   int64
#  1   Id               1538 non-null   int64
#  2   PID              1538 non-null   int64
#  3   MS SubClass      1538 non-null   int64
#  4   MS Zoning        1538 non-null   object
#  5   Lot Frontage     1538 non-null   float64
#  6   Lot Area         1538 non-null   int64
#  7   Street           1538 non-null   object
#  8   Lot Shape        1538 non-null   object
#  9   Land Contour     1538 non-null   object
#  10  Utilities        1538 non-null   object
#  11  Lot Config       1538 non-null   object
#  12  Land Slope       1538 non-null   object
#  13  Neighborhood     1538 non-null   object
#  14  Condition 1      1538 non-null   object
#  15  Condition 2      1538 non-null   object
#  16  Bldg Type        1538 non-null   object
# ...

# %%
# fill missing data in numerical columns with average of columns' values
# fill missing data in categorical columns with 'Unknown'
numerical_columns = test_cleaned.select_dtypes(include=['int', 'float']).columns
test_cleaned.loc[:, numerical_columns] = test_cleaned.loc[:, numerical_columns].fillna(test_cleaned[numerical_columns].mean())
categorical_columns = test_cleaned.select_dtypes(include=['object']).columns
test_cleaned.loc[:, categorical_columns] = test_cleaned.loc[:, categorical_columns].fillna('Unknown')
test_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 76 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       513 non-null    int64
#  1   Id               513 non-null    int64
#  2   PID              513 non-null    int64
#  3   MS SubClass      513 non-null    int64
#  4   MS Zoning        513 non-null    object
#  5   Lot Frontage     513 non-null    float64
#  6   Lot Area         513 non-null    int64
#  7   Street           513 non-null    object
#  8   Lot Shape        513 non-null    object
#  9   Land Contour     513 non-null    object
#  10  Utilities        513 non-null    object
#  11  Lot Config       513 non-null    object
#  12  Land Slope       513 non-null    object
#  13  Neighborhood     513 non-null    object
#  14  Condition 1      513 non-null    object
#  15  Condition 2      513 non-null    object
#  16  Bldg Type        513 non-null    object
# ...

# %%
train_cleaned.shape
# Out:
# (1538, 77)

# %%
test_cleaned.shape
# Out:
# (513, 76)

# %%
# save cleaned dataset
train_cleaned.to_csv('../data/train_cleaned.csv', index=False)

# %%
# save cleaned dataset
test_cleaned.to_csv('../data/test_cleaned.csv', index=False)
